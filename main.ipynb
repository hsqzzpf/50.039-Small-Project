# %%
import sys
import pickle
import numpy as np
import pandas as pd

from loss import MultiLabelNBLoss
from naive_bayes import NaiveBayes
from dataset import VOCDataset, collate_wrapper

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from torchvision import transforms
import torchvision.models as models

from eval import get_AP

import PIL

device = torch.device("cpu")

# %%
def print_nb_matrix(dataset, mat):
    cols = ["x={}".format(key) for key in dataset.labels_dict.keys()]
    rows = ["P({}|x)".format(key) for key in dataset.labels_dict.keys()]
    mat = pd.DataFrame(mat, columns=cols, index=rows).round(5).T
    print(mat)

# %%
batch_size = 48
def train(model, device, train_loader, optimiz, epoch, loss_fn):
    model.train()
    losses = []
    
    for idx, batch in enumerate(train_loader):
        data = batch.image.to(device)
        target = batch.labels.to(device)
        
        optimiz.zero_grad()
        output = model(data)
        loss = loss_fn(output, target)
        
        loss.backward()
        optimiz.step()
        
        losses.append(loss.item())
        print("Epoch: {}, Samples: {}/{}, Loss: {}".format(epoch,  
                                                           idx*batch_size,
                                                           len(train_loader)*batch_size,
                                                           loss.item()))
        train_loss = torch.mean(torch.tensor(losses))
        
    print("Epoch: {}".format(epoch))
    print("Training set: Average loss: {:.4f}".format(train_loss))
    return train_loss

# %%
def validate(model, device, val_loader, loss_fn):
    model.eval()
    val_loss = 0
    
    with torch.no_grad():
        for idx, batch in enumerate(val_loader):
            data = batch.image.to(device)
            target = batch.labels.to(device)
            output = model(data)
            
            batch_loss = loss_fn(output, target)
            val_loss += batch_loss.item()
            pred = torch.sigmoid(output)
            
            if idx == 0:
                predictions = pred
                targets = target
            else:
                predictions = torch.cat((predictions, pred))
                targets = torch.cat((targets, target))
    val_loss /= len(val_loader)
    print("Validation set: Average loss: {:.4f}".format(val_loss))
    print('                AP: {:.4f}'.format(
        get_AP(predictions.reshape(-1, 20), targets.reshape(-1, 20))))
    return val_loss, predictions, targets

# %%
directory = 'data/VOC2012'
def main(mode, num_epochs, num_workers, lr, sc, model_name=None):
    tr = transforms.Compose([transforms.RandomResizedCrop(300),
                             transforms.ToTensor(),
                             transforms.Normalize([0.4589, 0.4355, 0.4032],[0.2239, 0.2186, 0.2206])])

    augs = transforms.Compose([transforms.RandomResizedCrop(300),
                               transforms.RandomRotation(20),
                               transforms.ToTensor(),
                               transforms.Normalize([0.4589, 0.4355, 0.4032],[0.2239, 0.2186, 0.2206])])

    # Get the NB matrix from the dataset,
    # counting multiple instances of labels.
    nb_dataset = VOCDataset(directory, 'train', transforms=tr, multi_instance=True)
    nb = NaiveBayes(nb_dataset, 1)
    mat = nb.get_nb_matrix()
    print_nb_matrix(nb_dataset, mat)
    mat = torch.Tensor(mat).to(device)

    # Define the training dataset, removing
    # multiple instances for the training problem.
    train_set = VOCDataset(directory, 'train', transforms=augs, multi_instance=False)
    train_loader = DataLoader(train_set, batch_size=batch_size, collate_fn=collate_wrapper, shuffle=True, num_workers=num_workers)

    val_set = VOCDataset(directory, 'val', transforms=tr)
    val_loader = DataLoader(val_set, batch_size=batch_size, collate_fn=collate_wrapper, shuffle=True, num_workers=num_workers)

    model = models.resnet34(pretrained=True)
    model.fc = nn.Linear(512, 20)

    if model_name == None:
        train_losses = []
        val_losses = []
        curr_epoch = 0
    else:
        model.load_state_dict(torch.load(model_name + '.pt'))
        print('Loading history')
        train_losses = np.load('train_history_{}_{}.npy'.format(mode, model_name)).tolist()
        val_losses = np.load('val_history_{}_{}.npy'.format(mode, model_name)).tolist()
        curr_epoch = int(model_name.split('_')[-2])

    model.to(device)
    print('Starting optimizer with LR={}'.format(lr))
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)

    # ====================================== #
    # Use either:                            #
    # loss_function = nn.BCEWithLogitsLoss() #
    # loss_function = MultiLabelNBLoss(mat)  #
    # ====================================== #
    if mode == 'BCE':
        classwise_frequencies = np.array(list(train_set.classes_count.values()))
        minimum_frequency = np.min(classwise_frequencies)
        loss_weights = minimum_frequency / classwise_frequencies
        loss_weights = torch.Tensor(loss_weights).to(device)
        loss_function = nn.BCEWithLogitsLoss(weight=loss_weights)
    elif mode == 'NB':
        loss_function = MultiLabelNBLoss(mat, scaling_c=sc)

    try:
        for epoch in range(1, num_epochs + 1):
            train_loss = train(model, device, train_loader, optimizer, curr_epoch+1, loss_function)
            val_loss, predictions, targets = validate(model, device, val_loader, loss_function)

            print("Saving raw predictions for epoch {}...".format(curr_epoch+1))
            with open("pred_{}_{}.pkl".format(mode, curr_epoch+1), 'wb') as f:
                pred_targets = torch.cat((predictions.unsqueeze(0), targets.unsqueeze(0)))
                pickle.dump(pred_targets, f)

            if (len(val_losses) > 0) and (val_loss < min(val_losses)):
                torch.save(model.state_dict(), "lr{}_sc{}_model_{}_{}_{:.4f}.pt".format(lr, sc, mode, curr_epoch+1, val_loss))
                print("Saving model (epoch {}) with lowest validation loss: {}"
                    .format(epoch, val_loss))

            train_losses.append(train_loss)
            val_losses.append(val_loss)
            torch.save(model.state_dict(), 'temp_model.pt')
            curr_epoch += 1

        model_save_name = "stop_lr{}_sc{}_model_{}_{}_{:.4f}.pt".format(lr, sc, mode, curr_epoch, val_losses[-1])
        torch.save(model.state_dict(), model_save_name)

    except KeyboardInterrupt:
        model.load_state_dict(torch.load('temp_model.pt'))
        model_save_name = "pause_lr{}_sc{}_model_{}_{}_{:.4f}.pt".format(lr, sc, mode, curr_epoch, val_losses[-1])
        torch.save(model.state_dict(), model_save_name)
        print("Saving model (epoch {}) with current validation loss: {}".format(curr_epoch, val_losses[-1]))

    train_history = np.array(train_losses)
    val_history = np.array(val_losses)

    print('Saving history')
    np.save("train_history_{}_{}".format(mode, model_save_name[5:-3]), train_history)
    np.save("val_history_{}_{}".format(mode, model_save_name[5:-3]), val_history)

# %%
if __name__ == "__main__":
    main(mode='BCE', num_epochs=50, num_workers=16, lr=1e-3, sc=1e-3)
# Out:
# SET: train | TOTAL IMAGES: 5717
# SET: train | TOTAL LABELS: 15774
#                P(aeroplane|x)  P(bicycle|x)  P(bird|x)  P(boat|x)  \
# x=aeroplane           0.52448       0.00699    0.00699    0.02098
# x=bicycle             0.00267       0.19251    0.00535    0.01070
# x=bird                0.00629       0.01258    0.54717    0.03774
# x=boat                0.01167       0.01556    0.02335    0.40078
# x=bottle              0.00126       0.02652    0.00253    0.00253
# x=bus                 0.00656       0.03934    0.00328    0.00656
# x=car                 0.01740       0.05220    0.00464    0.01740
# x=cat                 0.00380       0.00760    0.01141    0.00380
# x=chair               0.00073       0.00798    0.00290    0.00218
# x=cow                 0.00719       0.02158    0.01439    0.01439
# x=diningtable         0.00148       0.00295    0.00295    0.00148
# x=dog                 0.00223       0.00446    0.01116    0.00670
# x=horse               0.00407       0.00407    0.00813    0.00407
# x=motorbike           0.00312       0.03738    0.00312    0.00935
# x=person              0.00944       0.04604    0.00715    0.02774
# x=pottedplant         0.00175       0.01920    0.00524    0.00524
# x=sheep               0.00575       0.00575    0.02874    0.00575
# x=sofa                0.00172       0.00687    0.00172    0.00515
# x=train               0.00575       0.01724    0.00575    0.01149
# x=tvmonitor           0.00214       0.00855    0.00427    0.00427
#
#                P(bottle|x)  P(bus|x)  P(car|x)  P(cat|x)  P(chair|x)  \
# x=aeroplane        0.00699   0.01399   0.10490   0.00699     0.00699
# x=bicycle          0.05615   0.03209   0.12032   0.00535     0.02941
# x=bird             0.01258   0.00629   0.02516   0.01887     0.02516
# x=boat             0.00778   0.00778   0.05837   0.00389     0.01167
# x=bottle           0.17803   0.00126   0.01768   0.01515     0.13131
# x=bus              0.00328   0.20656   0.30164   0.00328     0.00328
# x=car              0.01624   0.10673   0.29118   0.00696     0.01856
# x=cat              0.04563   0.00380   0.02281   0.20913     0.14449
# x=chair            0.07547   0.00073   0.01161   0.02758     0.22714
# x=cow              0.00719   0.00719   0.04317   0.00719     0.00719
# x=diningtable      0.15510   0.00148   0.00591   0.01477     0.32201
# x=dog              0.04464   0.00223   0.04464   0.04911     0.09598
# x=horse            0.01220   0.00813   0.04878   0.00407     0.01220
# x=motorbike        0.01246   0.02492   0.15576   0.00312     0.00935
# x=person           0.06920   0.03060   0.07950   0.01201     0.08207
# x=pottedplant      0.05934   0.00698   0.02094   0.02792     0.18674
# x=sheep            0.01724   0.00575   0.02874   0.01149     0.00575
# x=sofa             0.06186   0.00172   0.00344   0.06014     0.19072
# x=train            0.00575   0.01724   0.06897   0.00575     0.01724
# x=tvmonitor        0.09615   0.00214   0.00641   0.02778     0.23504
#
#                P(cow|x)  P(diningtable|x)  P(dog|x)  P(horse|x)  \
# x=aeroplane     0.00699           0.00699   0.00699     0.00699
# x=bicycle       0.00802           0.00535   0.00535     0.00267
# x=bird          0.01258           0.01258   0.03145     0.01258
# x=boat          0.00778           0.00389   0.01167     0.00389
# x=bottle        0.00126           0.13258   0.02525     0.00379
# x=bus           0.00328           0.00328   0.00328     0.00656
# x=car           0.00696           0.00464   0.02320     0.01392
# x=cat           0.00380           0.03802   0.08365     0.00380
# x=chair         0.00073           0.15820   0.03120     0.00218
# x=cow           0.57554           0.00719   0.03597     0.01439
# x=diningtable   0.00148           0.04727   0.00886     0.00148
# x=dog           0.01116           0.01339   0.22768     0.00893
# x=horse         0.00813           0.00407   0.01626     0.33740
# x=motorbike     0.00312           0.00312   0.00623     0.00623
# x=person        0.00743           0.05147   0.03746     0.03489
# x=pottedplant   0.00175           0.10820   0.02269     0.00349
# x=sheep         0.01149           0.00575   0.03448     0.00575
# x=sofa          0.00172           0.04811   0.09107     0.00172
# x=train         0.00575           0.00575   0.00575     0.00575
# x=tvmonitor     0.00214           0.04274   0.01709     0.00214
#
#                P(motorbike|x)  P(person|x)  P(pottedplant|x)  P(sheep|x)  \
# x=aeroplane           0.00699      0.23077           0.00699     0.00699
# x=bicycle             0.03209      0.43048           0.02941     0.00267
# x=bird                0.00629      0.15723           0.01887     0.03145
# x=boat                0.01167      0.37743           0.01167     0.00389
# x=bottle              0.00505      0.30556           0.04293     0.00379
# x=bus                 0.02623      0.35082           0.01311     0.00328
# x=car                 0.05800      0.32251           0.01392     0.00580
# x=cat                 0.00380      0.15970           0.06084     0.00760
# x=chair               0.00218      0.20827           0.07765     0.00073
# x=cow                 0.00719      0.18705           0.00719     0.01439
# x=diningtable         0.00148      0.26588           0.09158     0.00148
# x=dog                 0.00446      0.29241           0.02902     0.01339
# x=horse               0.00813      0.49593           0.00813     0.00407
# x=motorbike           0.19938      0.47975           0.02492     0.00623
# x=person              0.04404      0.31913           0.02860     0.01115
# x=pottedplant         0.01396      0.17452           0.18499     0.00175
# x=sheep               0.01149      0.22414           0.00575     0.56897
# x=sofa                0.00344      0.26976           0.08763     0.00172
# x=train               0.00575      0.50000           0.03448     0.00575
# x=tvmonitor           0.00214      0.24145           0.06838     0.00214
#
#                P(sofa|x)  P(train|x)  P(tvmonitor|x)
# x=aeroplane      0.00699     0.00699         0.00699
# x=bicycle        0.01070     0.00802         0.01070
# x=bird           0.00629     0.00629         0.01258
# x=boat           0.01167     0.00778         0.00778
# x=bottle         0.04545     0.00126         0.05682
# x=bus            0.00328     0.00984         0.00328
# x=car            0.00232     0.01392         0.00348
# x=cat            0.13308     0.00380         0.04943
# x=chair          0.08055     0.00218         0.07983
# x=cow            0.00719     0.00719         0.00719
# x=diningtable    0.04136     0.00148         0.02954
# x=dog            0.11830     0.00223         0.01786
# x=horse          0.00407     0.00407         0.00407
# x=motorbike      0.00623     0.00312         0.00312
# x=person         0.04490     0.02488         0.03231
# x=pottedplant    0.08901     0.01047         0.05585
# x=sheep          0.00575     0.00575         0.00575
# x=sofa           0.06357     0.00172         0.09622
# x=train          0.00575     0.26437         0.00575
# x=tvmonitor      0.11966     0.00214         0.11325
# SET: train | TOTAL IMAGES: 5717
# SET: train | TOTAL LABELS: 8863
# SET: val | TOTAL IMAGES: 5823
# SET: val | TOTAL LABELS: 8856
# Starting optimizer with LR=0.001
# Epoch: 1, Samples: 0/5760, Loss: 0.39016082882881165
# Epoch: 1, Samples: 48/5760, Loss: 0.39579707384109497
# Epoch: 1, Samples: 96/5760, Loss: 0.38974565267562866
# Epoch: 1, Samples: 144/5760, Loss: 0.3935873210430145
# Process Process-19:
# Process Process-30:
# Process Process-31:
# Process Process-25:
# Process Process-28:
# Process Process-20:
# Process Process-22:
# Process Process-21:
# Process Process-18:
# Process Process-24:
# Process Process-29:
# Process Process-23:
# Process Process-17:
# Process Process-26:
# Process Process-27:
# Process Process-32:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x1a2e1450f0>>
# Traceback (most recent call last):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 961, in __del__
#     self._shutdown_workers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 941, in _shutdown_workers
#     w.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 124, in join
#     res = self._popen.wait(timeout)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/popen_fork.py", line 50, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
# Traceback (most recent call last):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-62ed324c0842> in main(mode, num_epochs, num_workers, lr, sc, model_name)
#      61         for epoch in range(1, num_epochs + 1):
# ---> 62             train_loss = train(model, device, train_loader, optimizer, curr_epoch+1, loss_function)
#      63             val_loss, predictions, targets = validate(model, device, val_loader, loss_function)
#
# <ipython-input-35-85131e3bc266> in train(model, device, train_loader, optimiz, epoch, loss_fn)
#      10         optimiz.zero_grad()
# ---> 11         output = model(data)
#      12         loss = loss_fn(output, target)
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#     215     def forward(self, x):
# --> 216         return self._forward_impl(x)
#     217
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     206         x = self.layer3(x)
# --> 207         x = self.layer4(x)
#     208
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#      63
# ---> 64         out = self.conv2(out)
#      65         out = self.bn2(out)
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-e2974aa70a5b> in <module>
#       1 if __name__ == "__main__":
# ----> 2     main(mode='BCE', num_epochs=50, num_workers=16, lr=1e-3, sc=1e-3)
#
# <ipython-input-37-62ed324c0842> in main(mode, num_epochs, num_workers, lr, sc, model_name)
#      82
#      83     except KeyboardInterrupt:
# ---> 84         model.load_state_dict(torch.load('temp_model.pt'))
#      85         model_save_name = "pause_lr{}_sc{}_model_{}_{}_{:.4f}.pt".format(lr, sc, mode, curr_epoch, val_losses[-1])
#      86         torch.save(model.state_dict(), model_save_name)
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     523         pickle_load_args['encoding'] = 'utf-8'
#     524
# --> 525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     210 def _open_file_like(name_or_buffer, mode):
#     211     if _is_path(name_or_buffer):
# --> 212         return _open_file(name_or_buffer, mode)
#     213     else:
#     214         if 'w' in mode:
#
# ~/opt/miniconda3/envs/ml/lib/python3.6/site-packages/torch/serialization.py in __init__(self, name, mode)
#     191 class _open_file(_opener):
#     192     def __init__(self, name, mode):
# --> 193         super(_open_file, self).__init__(open(name, mode))
#     194
#     195     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_model.pt'
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/Users/wangtianduo/opt/miniconda3/envs/ml/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
